# %%
import pyodbc
import pandas as pd
from datetime import datetime, date, timedelta
import requests
import concurrent.futures
import time
import random
import logging

# 設置日誌
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='stock_update.log',
    filemode='a'
)
logger = logging.getLogger('StockUpdater')

class FastStockUpdater:
    def __init__(self, server="IDEAPAD701\\MSSQLSERVER01", database="stock"):
        """初始化更新器"""
        self.connection_string = f'DRIVER={{SQL Server}};SERVER={server};DATABASE={database};Trusted_Connection=yes;'
        self.session = requests.Session()
    
    def connect_db(self):
        """建立數據庫連接"""
        return pyodbc.connect(self.connection_string)
    
    def get_stock_tables(self):
        """獲取所有股票表名"""
        conn = self.connect_db()
        try:
            cursor = conn.cursor()
            # 獲取所有表，不做過濾
            cursor.execute("""
            SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES 
            WHERE TABLE_TYPE = 'BASE TABLE'
            """)
            return [row[0] for row in cursor.fetchall()]
        finally:
            conn.close()
    
    def check_missing_data(self, stock_table, start_date):
        """檢查缺失的日期數據"""
        conn = self.connect_db()
        try:
            cursor = conn.cursor()
            try:
                cursor.execute(f"""
                SELECT [Date] FROM [stock].[dbo].[{stock_table}]
                WHERE [Date] >= '{start_date}'
                ORDER BY [Date]
                """)
                
                # 獲取實際日期
                actual_dates = {row[0].date() if hasattr(row[0], 'date') else row[0] for row in cursor.fetchall()}
                
                # 計算應該有的交易日 (排除週末)
                expected_dates = set()
                start = datetime.strptime(start_date, '%Y-%m-%d')
                end = datetime.now()
                current = start
                one_day = timedelta(days=1)
                
                while current <= end:
                    if current.weekday() < 5:  # 排除週末
                        expected_dates.add(current.date())
                    current = current + one_day
                
                # 返回缺失的日期
                return sorted(list(expected_dates - actual_dates))
            except Exception:
                # 如果執行失敗，可能是表結構不符合股票數據表格式
                logger.warning(f"表 {stock_table} 可能不是股票數據表或結構不符")
                return []
        finally:
            conn.close()
    
    def get_stock_number(self, stock_table):
        """嘗試從表名找出股票代碼"""
        # 處理特殊情況: 直接從表名提取數字部分
        if any(c.isdigit() for c in stock_table):
            digits = ''.join(c for c in stock_table if c.isdigit())
            if digits:
                logger.info(f"從表名 {stock_table} 直接提取股票代碼: {digits}")
                return digits
        
        # 從資料庫中獲取可能的代碼映射
        conn = self.connect_db()
        try:
            cursor = conn.cursor()
            
            # 檢查表是否存在
            try:
                # 檢查特定表是否存在
                cursor.execute("""
                SELECT COUNT(*) FROM INFORMATION_SCHEMA.TABLES 
                WHERE TABLE_NAME = 'StockNameMapping' AND TABLE_TYPE = 'BASE TABLE'
                """)
                
                table_exists = cursor.fetchone()[0] > 0
                
                # 如果表存在，嘗試查詢
                if table_exists:
                    cursor.execute("SELECT code FROM dbo.StockNameMapping WHERE name = ?", stock_table)
                    result = cursor.fetchone()
                    if result:
                        return result[0]
            except Exception as e:
                logger.error(f"查詢映射表失敗: {str(e)}")
            
            # 嘗試從其他表的已有數據判斷
            try:
                cursor.execute(f"""
                SELECT TOP 1 s2.TABLE_NAME
                FROM INFORMATION_SCHEMA.COLUMNS c1
                JOIN INFORMATION_SCHEMA.COLUMNS c2 ON c1.COLUMN_NAME = c2.COLUMN_NAME
                JOIN INFORMATION_SCHEMA.TABLES s1 ON c1.TABLE_NAME = s1.TABLE_NAME
                JOIN INFORMATION_SCHEMA.TABLES s2 ON c2.TABLE_NAME = s2.TABLE_NAME
                WHERE s1.TABLE_NAME = '{stock_table}'
                AND s2.TABLE_NAME LIKE '%TW'
                AND s1.TABLE_TYPE = 'BASE TABLE' AND s2.TABLE_TYPE = 'BASE TABLE'
                AND c1.DATA_TYPE = c2.DATA_TYPE
                """)
                
                result = cursor.fetchone()
                if result:
                    # 從TW結尾的表名中提取代碼
                    tw_table = result[0]
                    code = ''.join(c for c in tw_table if c.isdigit())
                    if code:
                        return code
            except Exception as e:
                logger.error(f"關聯查詢失敗: {str(e)}")
            
            # 最後嘗試從表名提取代碼部分
            return ''.join(c for c in stock_table if c.isdigit())
        finally:
            conn.close()
    
    def crawl_stock_data(self, stock_number, year, month, max_retries=3):
        """從台灣證交所爬取月度股票數據，含重試機制"""
        # 移除可能的中文和TW後綴
        stock_number = ''.join([c for c in stock_number if c.isdigit()])
        
        if not stock_number:
            return None
        
        for attempt in range(max_retries):
            try:
                # 隨機化請求頭，降低被封風險
                headers = {
                    'User-Agent': random.choice([
                        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 Chrome/91.0.4472.124',
                        'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7) Safari/605.1.15',
                        'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:89.0) Gecko/20100101 Firefox/89.0',
                        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36 Edg/91.0.864.59'
                    ]),
                    'Referer': 'https://www.twse.com.tw/zh/'
                }
                
                # 構建URL
                url = f"https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=json&date={year}{month:02d}01&stockNo={stock_number}"
                
                response = self.session.get(url, headers=headers, timeout=5)  # 縮短超時時間
                
                if response.status_code != 200:
                    logger.warning(f"請求失敗: HTTP {response.status_code}, 嘗試 {attempt+1}/{max_retries}")
                    continue
                    
                data = response.json()
                
                if not data.get('data'):
                    logger.warning(f"未找到數據: {stock_number} {year}-{month}")
                    return None
                    
                # 轉換為DataFrame
                df = pd.DataFrame(data['data'], columns=[
                    'Date', 'Volume', 'Volume_Value', 'Open', 
                    'High', 'Low', 'Close', 'Change', 'Trades'
                ])
                
                # 轉換日期格式
                df['Date'] = df['Date'].apply(lambda x: f"{int(x.split('/')[0])+1911}-{x.split('/')[1].zfill(2)}-{x.split('/')[2].zfill(2)}")
                    
                # 轉換數值
                for col in ['Open', 'High', 'Low', 'Close', 'Volume']:
                    df[col] = df[col].replace('--', '0').str.replace(',', '').astype(float)
                    
                return df
                
            except Exception as e:
                logger.error(f"爬取失敗 {stock_number} {year}-{month}: {str(e)}, 嘗試 {attempt+1}/{max_retries}")
                # 不休息，立即重試
                continue
        
        return None  # 所有重試都失敗

    def insert_stock_data(self, stock_table, data):
        """插入股票數據到數據庫"""
        if data is None or data.empty:
            return 0
            
        conn = self.connect_db()
        inserted = 0
        
        try:
            cursor = conn.cursor()
            
            for _, row in data.iterrows():
                try:
                    date_str = row['Date']
                    
                    # 檢查數值
                    if any(pd.isna(row[col]) for col in ['Open', 'High', 'Low', 'Close', 'Volume']):
                        continue
                        
                    # 檢查記錄是否已存在
                    cursor.execute(f"SELECT 1 FROM [stock].[dbo].[{stock_table}] WHERE [Date] = ?", date_str)
                    if cursor.fetchone():
                        continue
                        
                    # 插入新記錄
                    cursor.execute(f"""
                    INSERT INTO [stock].[dbo].[{stock_table}] 
                    ([Date], [Open], [High], [Low], [Close], [Volume], [created_at])
                    VALUES (?, ?, ?, ?, ?, ?, GETDATE())
                    """, 
                    date_str, float(row['Open']), float(row['High']), 
                    float(row['Low']), float(row['Close']), float(row['Volume']))
                    
                    inserted += 1
                        
                except Exception as e:
                    logger.error(f"插入記錄失敗 {date_str}: {str(e)}")
                    continue
                    
            conn.commit()
            return inserted
            
        except Exception as e:
            logger.error(f"批量插入失敗 {stock_table}: {str(e)}")
            return 0
        finally:
            conn.close()
    
    def process_stock_table(self, stock_table, start_date):
        """處理單個股票表的數據更新"""
        try:
            logger.info(f"處理表: {stock_table}")
            print(f"處理表: {stock_table}")  # 同時在控制台顯示
            
            missing_dates = self.check_missing_data(stock_table, start_date)
            
            if not missing_dates:
                logger.info(f"{stock_table}: 數據完整")
                return 0
                
            logger.info(f"{stock_table}: 缺失 {len(missing_dates)} 筆數據")
            
            # 找出股票代碼
            stock_number = self.get_stock_number(stock_table)
            logger.info(f"使用股票代碼: {stock_number}")
            
            # 按月份分組
            month_groups = {}
            for d in missing_dates:
                key = (d.year, d.month)
                if key not in month_groups:
                    month_groups[key] = []
                month_groups[key].append(d)
            
            total_inserted = 0
            
            # 逐月處理
            for (year, month), dates in month_groups.items():
                logger.info(f"處理 {year}-{month} 月數據...")
                
                # 爬取月度數據
                monthly_data = self.crawl_stock_data(stock_number, year, month)
                
                if monthly_data is not None:
                    # 過濾出缺失日期的數據
                    target_dates = [d.strftime('%Y-%m-%d') for d in dates]
                    filtered_data = monthly_data[monthly_data['Date'].isin(target_dates)]
                    
                    if not filtered_data.empty:
                        # 插入數據
                        inserted = self.insert_stock_data(stock_table, filtered_data)
                        total_inserted += inserted
                        logger.info(f"成功插入 {inserted} 筆 {year}-{month} 數據")
                    else:
                        logger.warning(f"未找到 {year}-{month} 月的目標日期數據")
            
            logger.info(f"{stock_table}: 共補充 {total_inserted} 筆數據")
            return total_inserted
            
        except Exception as e:
            logger.error(f"處理 {stock_table} 時出錯: {str(e)}")
            return 0

    def process_tables_parallel(self, tables, start_date, max_workers=5):
        """並行處理多個表"""
        total_inserted = 0
        with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
            # 提交所有處理任務
            future_to_table = {executor.submit(self.process_stock_table, table, start_date): table for table in tables}
            completed = 0
            
            # 獲取結果
            for future in concurrent.futures.as_completed(future_to_table):
                table = future_to_table[future]
                try:
                    inserted = future.result()
                    total_inserted += inserted
                except Exception as e:
                    logger.error(f"處理表 {table} 時出錯: {str(e)}")
                
                completed += 1
                progress = (completed / len(tables)) * 100
                print(f"總進度: {progress:.1f}% ({completed}/{len(tables)})")
        
        return total_inserted

def main():
    start_time = time.time()
    
    # 設定開始日期
    start_date = "2025-02-11"
    
    print(f"開始以最快速度更新股票數據 (從 {start_date} 到今天)")
    logger.info(f"開始以最快速度更新股票數據 (從 {start_date} 到今天)")
    
    updater = FastStockUpdater()
    all_tables = updater.get_stock_tables()
    
    if not all_tables:
        print("未找到股票表")
        return
    
    print(f"找到 {len(all_tables)} 個表格，檢查哪些表格有缺失數據...")
    logger.info(f"找到 {len(all_tables)} 個表格，檢查哪些表格有缺失數據...")
    
    # 篩選出有缺失數據的表格
    tables_with_missing_data = []
    for table in all_tables:
        try:
            missing_dates = updater.check_missing_data(table, start_date)
            if missing_dates:
                tables_with_missing_data.append(table)
                print(f"表格 {table} 缺失 {len(missing_dates)} 筆數據")
        except Exception as e:
            logger.warning(f"檢查表格 {table} 時出錯: {str(e)}")
    
    if not tables_with_missing_data:
        print("沒有表格需要更新，所有數據都是最新的")
        return
    
    print(f"\n找到 {len(tables_with_missing_data)} 個有缺失數據的表格，開始更新...")
    logger.info(f"找到 {len(tables_with_missing_data)} 個有缺失數據的表格，開始更新...")
    
    # 使用並行處理加速，只處理有缺失數據的表格
    print("\n開始並行處理...")
    total_inserted = updater.process_tables_parallel(tables_with_missing_data, start_date, max_workers=8)
    
    end_time = time.time()
    elapsed = end_time - start_time
    
    print(f"\n處理完成! 共補充 {total_inserted} 筆數據")
    print(f"處理時間: {elapsed:.2f} 秒")
    logger.info(f"處理完成! 共補充 {total_inserted} 筆數據, 耗時: {elapsed:.2f} 秒")

if __name__ == "__main__":
    main()

# 另存為 analyze_5880.py
analyze_5880 = {
    'cell_type': 'code',
    'metadata': {
        'id': 'analyze_5880',
        'language': 'python'
    },
    'source': [
        "# 分析合庫金(5880)股票",
        "try:",
        "    conn = connect_to_database()",
        "    if conn is None:",
        "        print(\"無法連接到資料庫\")",
        "    else:",
        "        try:",
        "            # 讀取合庫金股票數據",
        "            query = \"\"\"",
        "            SELECT [Date] as 交易日期,",
        "                   [Open] as 開盤價,",
        "                   [High] as 最高價,",
        "                   [Low] as 最低價,",
        "                   [Close] as 收盤價,",
        "                   [Volume] as 成交量",
        "            FROM [stock].[dbo].[5880TW合庫金]",
        "            ORDER BY [Date]",
        "            \"\"\"",
        "            ",
        "            df_5880 = pd.read_sql(query, conn)",
        "            ",
        "            # 添加股票代碼和名稱列",
        "            df_5880['股票代碼'] = '5880'",
        "            df_5880['股票名稱'] = '合庫金'",
        "            ",
        "            print(\"\n合庫金(5880)基本統計資訊:\")",
        "            print(f\"資料期間: {df_5880['交易日期'].min()} 到 {df_5880['交易日期'].max()}\")",
        "            print(f\"總交易天數: {len(df_5880)}\")",
        "            print(f\"最高價: {df_5880['最高價'].max():.2f}\")",
        "            print(f\"最低價: {df_5880['最低價'].min():.2f}\")",
        "            print(f\"平均收盤價: {df_5880['收盤價'].mean():.2f}\")",
        "            ",
        "            # 進行股價區間分析",
        "            interval_result = price_interval_analysis(df_5880, '5880', m=5)",
        "            if interval_result is not None:",
        "                print(\"\n股價區間分析:\")",
        "                print(interval_result)",
        "            ",
        "            # 進行股價趨勢分析",
        "            trend_result = analyze_stock_trend(df_5880, '5880')",
        "            if trend_result is not None:",
        "                # 計算年度收益率",
        "                annual_returns = calculate_annual_returns(trend_result)",
        "                print(\"\n年度收益率:\")",
        "                print(annual_returns)",
        "                ",
        "                # 計算波動率",
        "                daily_returns = trend_result['收盤價'].pct_change()",
        "                volatility = daily_returns.std() * np.sqrt(252) * 100  # 年化波動率",
        "                print(f\"\n年化波動率: {volatility:.2f}%\")",
        "                ",
        "        except Exception as e:",
        "            print(f\"分析過程中出錯: {e}\")",
        "        finally:",
        "            conn.close()",
        "            print(\"\n資料庫連接已關閉\")",
        "except Exception as e:",
        "    print(f\"執行分析時發生錯誤: {e}\")"
    ]
}
# Out:
# 開始以最快速度更新股票數據 (從 2025-02-11 到今天)
# 找到 1276 個表格，檢查哪些表格有缺失數據...
# 表格 5533TW皇鼎 缺失 116 筆數據
# 表格 00652TW 缺失 116 筆數據
# 表格 2610TW華航 缺失 116 筆數據
# 表格 9912TW偉聯 缺失 116 筆數據
# 表格 2458TW義隆 缺失 116 筆數據
# 表格 2360TW致茂 缺失 116 筆數據
# 表格 6753TW龍德造船 缺失 116 筆數據
# 表格 3048TW益登 缺失 116 筆數據
# 表格 2059TW川湖 缺失 116 筆數據
# 表格 6283TW淳安 缺失 116 筆數據
# 表格 1713TW國化 缺失 116 筆數據
# 表格 1472TW三洋實業 缺失 116 筆數據
# 表格 4583TW台灣精銳 缺失 116 筆數據
# 表格 1304TW台聚 缺失 116 筆數據
# 表格 3583TW辛耘 缺失 116 筆數據
# 表格 6742TW澤米 缺失 116 筆數據
# 表格 00956TW 缺失 116 筆數據
# 表格 6288TW聯嘉 缺失 116 筆數據
# 表格 00783TW 缺失 116 筆數據
# 表格 2888ATW 缺失 116 筆數據
# 表格 00653LTW 缺失 116 筆數據
# 表格 2611TW志信 缺失 116 筆數據
# 表格 9911TW櫻花 缺失 116 筆數據
# 表格 2459TW敦吉 缺失 116 筆數據
# 表格 8081TW致新 缺失 116 筆數據
# 表格 2362TW藍天 缺失 116 筆數據
# 表格 6743TW安普新 缺失 116 筆數據
# 表格 2062TW橋椿 缺失 116 筆數據
# 表格 1714TW和桐 缺失 116 筆數據
# 表格 1473TW台南 缺失 116 筆數據
# 表格 4588TW玖鼎電力 缺失 116 筆數據
# 表格 2460TW建通 缺失 116 筆數據
# 表格 1305TW華夏 缺失 116 筆數據
# 表格 3591TW艾笛森 缺失 116 筆數據
# 表格 00954TW 缺失 116 筆數據
# 表格 3049TW精金 缺失 116 筆數據
# 表格 00830TW 缺失 116 筆數據
# 表格 2888BTW 缺失 116 筆數據
# 表格 00654RTW 缺失 116 筆數據
# 表格 2612TW中航 缺失 116 筆數據
# 表格 9914TW美利達 缺失 116 筆數據
# 表格 4722TW國精化 缺失 116 筆數據
# 表格 8101TW華冠 缺失 116 筆數據
# 表格 3588TW通嘉 缺失 116 筆數據
# 表格 2363TW矽統 缺失 116 筆數據
# 表格 2069TW運錩 缺失 116 筆數據
# 表格 6285TW啟碁 缺失 116 筆數據
# 表格 2889TW國票金 缺失 116 筆數據
# 表格 1717TW長興 缺失 116 筆數據
# 表格 5534TW長虹 缺失 116 筆數據
# 表格 1474TW弘裕 缺失 116 筆數據
# 表格 4720TW德淵 缺失 116 筆數據
# 表格 1307TW三芳 缺失 116 筆數據
# 表格 3593TW力銘 缺失 116 筆數據
# 表格 1419TW新紡 缺失 116 筆數據
# 表格 4104TW佳醫 缺失 116 筆數據
# 表格 020034TW 缺失 116 筆數據
# 表格 00911TW 缺失 116 筆數據
# 表格 00690TW 缺失 116 筆數據
# 表格 2809TW京城銀 缺失 116 筆數據
# 表格 2504TW國產 缺失 116 筆數據
# 表格 8443TW阿瘦 缺失 116 筆數據
# 表格 2409TW友達 缺失 116 筆數據
# 表格 6901TW鑽石投資 缺失 116 筆數據
# 表格 2302TW麗正 缺失 116 筆數據
# 表格 6552TW易華電 缺失 116 筆數據
# 表格 00912TW 缺失 116 筆數據
# 表格 1810TW和成 缺失 116 筆數據
# 表格 6168TW宏齊 缺失 116 筆數據
# 表格 1539TW巨庭 缺失 116 筆數據
# 表格 1423TW利華 缺失 116 筆數據
# 表格 4119TW旭富 缺失 116 筆數據
# 表格 6902TWGOGOLOOK-創 缺失 116 筆數據
# 表格 020036TW 缺失 116 筆數據
# 表格 3312TW弘憶股 缺失 116 筆數據
# 表格 3013TW晟銘電 缺失 116 筆數據
# 表格 00692TW 缺失 116 筆數據
# 表格 2816TW旺旺保 缺失 116 筆數據
# 表格 2505TW國揚 缺失 116 筆數據
# 表格 4108TW懷特 缺失 116 筆數據
# 表格 2412TW中華電 缺失 116 筆數據
# 表格 2303TW聯電 缺失 116 筆數據
# 表格 6558TW興能高 缺失 116 筆數據
# 表格 3014TW聯陽 缺失 116 筆數據
# 表格 1817TW凱撒衛 缺失 116 筆數據
# 表格 6177TW達麗 缺失 116 筆數據
# 表格 00693UTW 缺失 116 筆數據
# 表格 2812TW台中銀 缺失 116 筆數據
# 表格 1540TW喬福 缺失 116 筆數據
# 表格 4967TW十銓 缺失 116 筆數據
# 表格 1432TW大魯閣 缺失 116 筆數據
# 表格 020037TW 缺失 116 筆數據
# 表格 3321TW同泰 缺失 116 筆數據
# 表格 00913TW 缺失 116 筆數據
# 表格 0055TW 缺失 116 筆數據
# 表格 2506TW太設 缺失 116 筆數據
# 表格 2413TW環科 缺失 116 筆數據
# 表格 6914TW阜爾運通 缺失 116 筆數據
# 表格 2305TW全友 缺失 116 筆數據
# 表格 6585TW鼎基 缺失 116 筆數據
# 表格 1903TW士紙 缺失 116 筆數據
# 表格 6166TW凌華 缺失 116 筆數據
# 表格 1541TW錩泰 缺失 116 筆數據
# 表格 4977TW眾達-KY 缺失 116 筆數據
# 表格 1434TW福懋 缺失 116 筆數據
# 表格 4106TW雃博 缺失 116 筆數據
# 表格 6906TW現觀科 缺失 116 筆數據
# 表格 020038TW 缺失 116 筆數據
# 表格 3338TW泰碩 缺失 116 筆數據
# 表格 6573TW虹揚-KY 缺失 116 筆數據
# 表格 00915TW 缺失 116 筆數據
# 表格 3015TW全漢 缺失 116 筆數據
# 表格 00700TW 缺失 116 筆數據
# 表格 2820TW華票 缺失 116 筆數據
# 表格 4976TW佳凌 缺失 116 筆數據
# 表格 0056TW 缺失 116 筆數據
# 表格 2509TW全坤建 缺失 116 筆數據
# 表格 8467TW波力-KY 缺失 116 筆數據
# 表格 2414TW精技 缺失 116 筆數據
# 表格 8072TW陞泰 缺失 116 筆數據
# 表格 1303TW南亞 缺失 116 筆數據
# 表格 3576TW聯合再生 缺失 116 筆數據
# 表格 00960TW 缺失 116 筆數據
# 表格 3047TW訊舟 缺失 116 筆數據
# 表格 00775BTW 缺失 116 筆數據
# 表格 2888TW新光金 缺失 116 筆數據
#
# 找到 1276 個有缺失數據的表格，開始更新...
#
# 開始並行處理...
# 處理表: 5533TW皇鼎
# 處理表: 00652TW
# 處理表: 2610TW華航
# 處理表: 9912TW偉聯
# 處理表: 2458TW義隆
# 處理表: 2360TW致茂
# 處理表: 6753TW龍德造船
# 處理表: 3048TW益登
# 總進度: 0.1% (1/1276)處理表: 2059TW川湖
#
# 總進度: 0.2% (2/1276)
# 處理表: 6283TW淳安
# 總進度: 0.2% (3/1276)
# 處理表: 1713TW國化
# 總進度: 0.3% (4/1276)
# 處理表: 1472TW三洋實業
# 處理表: 4583TW台灣精銳
# 總進度: 0.4% (5/1276)
# 處理表: 1304TW台聚
# 總進度: 0.5% (6/1276)
# 處理表: 3583TW辛耘
# 總進度: 0.5% (7/1276)
# 處理表: 6742TW澤米總進度: 0.6% (8/1276)
#
# 總進度: 0.7% (9/1276)處理表: 00956TW
#
# 處理表: 6288TW聯嘉
# 總進度: 0.8% (10/1276)
# 處理表: 00783TW
# 總進度: 0.9% (11/1276)
# 處理表: 2888ATW
# 總進度: 0.9% (12/1276)
# 處理表: 00653LTW
# 總進度: 1.0% (13/1276)
# 總進度: 1.1% (14/1276)
# 處理表: 2611TW志信
# 處理表: 9911TW櫻花總進度: 1.2% (15/1276)
#
# 總進度: 1.3% (16/1276)處理表: 2459TW敦吉
#
# 總進度: 1.3% (17/1276)
# 處理表: 8081TW致新
# 處理表: 2362TW藍天
# 總進度: 1.4% (18/1276)
# 處理表: 6743TW安普新總進度: 1.5% (19/1276)
#
# 處理表: 2062TW橋椿
# 總進度: 1.6% (20/1276)
# 處理表: 1714TW和桐
# 總進度: 1.6% (21/1276)
# 處理表: 1473TW台南
# 總進度: 1.7% (22/1276)
# 處理表: 4588TW玖鼎電力
# 總進度: 1.8% (23/1276)
# 總進度: 1.9% (24/1276)
# 處理表: 2460TW建通
# 處理表: 1305TW華夏
# 總進度: 2.0% (25/1276)
# 總進度: 2.0% (26/1276)處理表: 3591TW艾笛森
#
# 處理表: 00954TW
# 總進度: 2.1% (27/1276)
# 總進度: 2.2% (28/1276)處理表: 3049TW精金
#
# 總進度: 2.3% (29/1276)
# 處理表: 00830TW
# 總進度: 2.4% (30/1276)
# 處理表: 2888BTW
# 總進度: 2.4% (31/1276)處理表: 00654RTW
#
# 處理表: 2612TW中航
# 總進度: 2.5% (32/1276)
# 處理表: 9914TW美利達總進度: 2.6% (33/1276)
#
# 總進度: 2.7% (34/1276)
# 處理表: 4722TW國精化
# 處理表: 8101TW華冠總進度: 2.7% (35/1276)
#
# 總進度: 2.8% (36/1276)
# 處理表: 3588TW通嘉
# 處理表: 2363TW矽統
# 總進度: 2.9% (37/1276)
# 處理表: 2069TW運錩
# 總進度: 3.0% (38/1276)
# 處理表: 6285TW啟碁
# 總進度: 3.1% (39/1276)
# 總進度: 3.1% (40/1276)
# 處理表: 2889TW國票金
# 總進度: 3.2% (41/1276)處理表: 1717TW長興
#
# 總進度: 3.3% (42/1276)
# 處理表: 5534TW長虹
# 總進度: 3.4% (43/1276)
# 處理表: 1474TW弘裕
# 處理表: 4720TW德淵
# 總進度: 3.4% (44/1276)
# 處理表: 1307TW三芳總進度: 3.5% (45/1276)
#
# 總進度: 3.6% (46/1276)
# 處理表: 3593TW力銘
# 總進度: 3.7% (47/1276)處理表: 00953BTW
#
# 處理表: 3050TW鈺德
# 總進度: 3.8% (48/1276)
# 總進度: 3.8% (49/1276)處理表: 00850TW
#
# 處理表: 2890TW永豐金
# 總進度: 3.9% (50/1276)
# 處理表: 5538TW東明-KY
# 總進度: 4.0% (51/1276)
# 處理表: 00655LTW總進度: 4.1% (52/1276)
#
# 總進度: 4.2% (53/1276)
# 處理表: 2613TW中櫃
# 總進度: 4.2% (54/1276)
# 處理表: 9917TW中保科
# 總進度: 4.3% (55/1276)處理表: 2461TW光群雷
#
# 處理表: 8103TW瀚荃總進度: 4.4% (56/1276)
#
# 處理表: 3592TW瑞鼎
# 總進度: 4.5% (57/1276)
# 處理表: 2364TW倫飛
# 總進度: 4.5% (58/1276)
# 處理表: 6754TW匯僑設計
# 總進度: 4.6% (59/1276)
# 處理表: 2101TW南港
# 總進度: 4.7% (60/1276)
# 總進度: 4.8% (61/1276)
# 處理表: 6405TW悅城
# 總進度: 4.9% (62/1276)
# 處理表: 1718TW中纖
# 處理表: 1475TW業旺總進度: 4.9% (63/1276)
#
# 處理表: 2462TW良得電
# 總進度: 5.0% (64/1276)
# 總進度: 5.1% (65/1276)處理表: 1308TW亞聚
#
# 總進度: 5.2% (66/1276)
# 處理表: 00961TW
# 處理表: 3051TW力特總進度: 5.3% (67/1276)
#
# 處理表: 00851TW總進度: 5.3% (68/1276)
#
# 總進度: 5.4% (69/1276)
# 處理表: 00656RTW
# 總進度: 5.5% (70/1276)處理表: 2614TW東森
#
# 處理表: 9919TW康那香
# 總進度: 5.6% (71/1276)
# 處理表: 8104TW錸寶
# 總進度: 5.6% (72/1276)
# 總進度: 5.7% (73/1276)處理表: 2365TW昆盈
#
# 處理表: 6757TW台灣虎航總進度: 5.8% (74/1276)
#
# 處理表: 3054TW立萬利總進度: 5.9% (75/1276)
#
# 處理表: 2102TW泰豐總進度: 6.0% (76/1276)
#
# 處理表: 6409TW旭隼
# 總進度: 6.0% (77/1276)
# 總進度: 6.1% (78/1276)處理表: 1720TW生達
#
# 總進度: 6.2% (79/1276)
# 處理表: 5546TW永固-KY
# 處理表: 9918TW欣天然總進度: 6.3% (80/1276)
#
# 處理表: 1476TW儒鴻總進度: 6.3% (81/1276)
#
# 處理表: 4737TW華廣總進度: 6.4% (82/1276)
#
# 總進度: 6.5% (83/1276)
# 處理表: 8105TW凌巨
# 總進度: 6.6% (84/1276)處理表: 1309TW台達化
#
# 總進度: 6.7% (85/1276)
# 處理表: 2367TW燿華
# 總進度: 6.7% (86/1276)處理表: 6756TW威鋒電子
#
# 處理表: 00962TW
# 總進度: 6.8% (87/1276)
# 處理表: 00852LTW總進度: 6.9% (88/1276)
#
# 總進度: 7.0% (89/1276)
# 處理表: 2891TW中信金
# 處理表: 5607TW遠雄港
# 總進度: 7.1% (90/1276)
# 總進度: 7.1% (91/1276)處理表: 00657TW
#
# 處理表: 2615TW萬海
# 總進度: 7.2% (92/1276)
# 總進度: 7.3% (93/1276)
# 處理表: 9921TW巨大
# 總進度: 7.4% (94/1276)處理表: 4739TW康普
#
# 總進度: 7.4% (95/1276)處理表: 2464TW盟立
#
# 總進度: 7.5% (96/1276)
# 處理表: 6768TW志強-KY
# 總進度: 7.6% (97/1276)
# 處理表: 2103TW台橡
# 總進度: 7.7% (98/1276)處理表: 6412TW群電
#
# 總進度: 7.8% (99/1276)處理表: 1721TW三晃
#
# 總進度: 7.8% (100/1276)處理表: 5608TW四維航
#
# 總進度: 7.9% (101/1276)處理表: 1477TW聚陽
#
# 處理表: 4736TW泰博
# 總進度: 8.0% (102/1276)
# 處理表: 1310TW台苯
# 總進度: 8.1% (103/1276)
# 處理表: 3596TW智易
# 總進度: 8.2% (104/1276)
# 總進度: 8.2% (105/1276)處理表: 6770TW力積電
#
# 總進度: 8.3% (106/1276)處理表: 00963TW
#
# 總進度: 8.4% (107/1276)處理表: 3052TW夆典
#
# 處理表: 00861TW
# 總進度: 8.5% (108/1276)
# 總進度: 8.5% (109/1276)處理表: 2891BTW
#
# 總進度: 8.6% (110/1276)處理表: 00657KTW
#
# 處理表: 2616TW山隆
# 總進度: 8.7% (111/1276)
# 處理表: 4746TW台耀
# 總進度: 8.8% (112/1276)
# 總進度: 8.9% (113/1276)
# 處理表: 2465TW麗臺
# 處理表: 8110TW華東
# 總進度: 8.9% (114/1276)
# 總進度: 9.0% (115/1276)處理表: 2368TW金像電
#
# 處理表: 3055TW蔚華科
# 總進度: 9.1% (116/1276)
# 總進度: 9.2% (117/1276)處理表: 2104TW國際中橡
#
# 處理表: 6414TW樺漢
# 總進度: 9.2% (118/1276)
# 總進度: 9.3% (119/1276)
# 處理表: 1722TW台肥
# 總進度: 9.4% (120/1276)處理表: 1503TW士電
#
# 總進度: 9.5% (121/1276)
# 處理表: 8112TW至上
# 總進度: 9.6% (122/1276)處理表: 1312TW國喬
#
# 處理表: 3605TW宏致總進度: 9.6% (123/1276)
#
# 處理表: 00964TW總進度: 9.7% (124/1276)
#
# 處理表: 3056TW富華新總進度: 9.8% (125/1276)
#
# 總進度: 9.9% (126/1276)處理表: 6415TW矽力*-KY
#
# 總進度: 10.0% (127/1276)處理表: 00865BTW
#
# 總進度: 10.0% (128/1276)
# 處理表: 2892TW第一金
# 處理表: 00660TW總進度: 10.1% (129/1276)
#
# 處理表: 2617TW台航
# 總進度: 10.2% (130/1276)
# 處理表: 9924TW福興
# 總進度: 10.3% (131/1276)
# 處理表: 2466TW冠西電總進度: 10.3% (132/1276)
#
# 處理表: 2369TW菱生
# 總進度: 10.4% (133/1276)
# 處理表: 2105TW正新總進度: 10.5% (134/1276)
#
# 總進度: 10.6% (135/1276)
# 處理表: 2891CTW
# 總進度: 10.7% (136/1276)處理表: 1723TW中碳
#
# 總進度: 10.7% (137/1276)
# 處理表: 5871TW中租-KY
# 總進度: 10.8% (138/1276)
# 處理表: 1504TW東元
# 總進度: 10.9% (139/1276)處理表: 1312ATW
#
# 總進度: 11.0% (140/1276)
# 處理表: 3607TW谷崧
# 處理表: 00965TW總進度: 11.1% (141/1276)
#
# 總進度: 11.1% (142/1276)
# 總進度: 11.2% (143/1276)
# 處理表: 00875TW
# 處理表: 00661TW
# 處理表: 2630TW亞航總進度: 11.3% (144/1276)
#
# 總進度: 11.4% (145/1276)
# 處理表: 9925TW新保
# 總進度: 11.4% (146/1276)
# 處理表: 2467TW志聖
# 總進度: 11.5% (147/1276)
# 處理表: 8112ATW
# 處理表: 3617TW碩天
# 總進度: 11.6% (148/1276)
# 處理表: 2371TW大同
# 總進度: 11.7% (149/1276)
# 處理表: 6771TW平和環保-創
# 總進度: 11.8% (150/1276)
# 處理表: 2106TW建大
# 總進度: 11.8% (151/1276)
# 總進度: 11.9% (152/1276)處理表: 6416TW瑞祺電通
#
# 總進度: 12.0% (153/1276)
# 處理表: 1725TW元禎
# 總進度: 12.1% (154/1276)
# 處理表: 5706TW鳳凰
# 總進度: 12.1% (155/1276)處理表: 1506TW正道
#
# 總進度: 12.2% (156/1276)處理表: 4755TW三福化
#
# 總進度: 12.3% (157/1276)處理表: 8114TW振樺電
#
# 處理表: 1313TW聯成總進度: 12.4% (158/1276)
#
# 總進度: 12.5% (159/1276)
# 處理表: 00971TW
# 處理表: 3057TW喬鼎
# 總進度: 12.5% (160/1276)
# 總進度: 12.6% (161/1276)處理表: 00876TW
#
# 處理表: 2897BTW
# 總進度: 12.7% (162/1276)
# 總進度: 12.8% (163/1276)處理表: 00662TW
#
# 總進度: 12.9% (164/1276)處理表: 2633TW台灣高鐵
#
# 總進度: 12.9% (165/1276)處理表: 9926TW新海
#
# 總進度: 13.0% (166/1276)處理表: 2468TW華經
#
# 處理表: 8131TW福懋科
# 總進度: 13.1% (167/1276)
# 總進度: 13.2% (168/1276)處理表: 2373TW震旦行
#
# 處理表: 6776TW展碁國際
# 總進度: 13.2% (169/1276)
# 總進度: 13.3% (170/1276)處理表: 3058TW立德
#
# 處理表: 2107TW厚生總進度: 13.4% (171/1276)
#
# 處理表: 6423TW億而得-創總進度: 13.5% (172/1276)
#
# 總進度: 13.6% (173/1276)
# 處理表: 2897TW王道銀行
# 總進度: 13.6% (174/1276)
# 處理表: 1726TW永記
# 總進度: 13.7% (175/1276)處理表: 5871ATW
#
# 總進度: 13.8% (176/1276)處理表: 1512TW瑞利
#
# 處理表: 4763TW材料-KY
# 總進度: 13.9% (177/1276)
# 總進度: 13.9% (178/1276)處理表: 1314TW中石化
#
# 處理表: 3622TW洋華總進度: 14.0% (179/1276)
#
# 總進度: 14.1% (180/1276)處理表: 2374TW佳能
#
# 總進度: 14.2% (181/1276)
# 處理表: 6781TWAES-KY
# 總進度: 14.3% (182/1276)
# 處理表: 00972TW
# 總進度: 14.3% (183/1276)處理表: 00878TW
#
# 處理表: 5876TW上海商銀
# 總進度: 14.4% (184/1276)
# 處理表: 00663LTW
# 總進度: 14.5% (185/1276)
# 總進度: 14.6% (186/1276)處理表: 2618TW長榮航
#
# 總進度: 14.7% (187/1276)處理表: 9927TW泰銘
#
# 總進度: 14.7% (188/1276)處理表: 2471TW資通
#
# 處理表: 3645TW達邁總進度: 14.8% (189/1276)
#
# 總進度: 14.9% (190/1276)
# 處理表: 2108TW南帝
# 處理表: 6426TW統新
# 總進度: 15.0% (191/1276)
# 處理表: 1727TW中華化
# 總進度: 15.0% (192/1276)
# 處理表: 9930TW中聯資源
# 總進度: 15.1% (193/1276)
# 總進度: 15.2% (194/1276)處理表: 1513TW中興電
#
# 處理表: 4764TW雙鍵
# 總進度: 15.3% (195/1276)
# 處理表: 1315TW達新總進度: 15.4% (196/1276)
#
# 處理表: 6782TW視陽
# 總進度: 15.4% (197/1276)
# 處理表: 01001TTW
# 總進度: 15.5% (198/1276)
# 處理表: 3059TW華晶科總進度: 15.6% (199/1276)
#
# 處理表: 00881TW
# 總進度: 15.7% (200/1276)
# 處理表: 2901TW欣欣總進度: 15.8% (201/1276)
#
# 總進度: 15.8% (202/1276)
# 處理表: 00664RTW
# 處理表: 2634TW漢翔
# 總進度: 15.9% (203/1276)
# 處理表: 9929TW秋雨總進度: 16.0% (204/1276)
#
# 處理表: 2472TW立隆電
# 總進度: 16.1% (205/1276)
# 處理表: 8150TW南茂
# 總進度: 16.1% (206/1276)
# 總進度: 16.2% (207/1276)處理表: 2375TW凱美
#
# 總進度: 16.3% (208/1276)
# 處理表: 3060TW銘異
# 總進度: 16.4% (209/1276)處理表: 2109TW華豐
#
# 總進度: 16.5% (210/1276)
# 處理表: 6431TW光麗-KY
# 總進度: 16.5% (211/1276)處理表: 2903TW遠百
#
# 總進度: 16.6% (212/1276)
# 處理表: 1730TW花仙子
# 處理表: 5880TW合庫金
# 總進度: 16.7% (213/1276)
# 處理表: 1514TW亞力
# 總進度: 16.8% (214/1276)
# 處理表: 4770TW上品
# 總進度: 16.8% (215/1276)
# 總進度: 16.9% (216/1276)處理表: 2474TW可成
#
# 處理表: 1316TW上曜總進度: 17.0% (217/1276)
#
# 總進度: 17.1% (218/1276)處理表: 3653TW健策
#
# 總進度: 17.2% (219/1276)
# 處理表: 01002TTW
# 處理表: 00882TW總進度: 17.2% (220/1276)
#
# 總進度: 17.3% (221/1276)
# 處理表: 00665LTW
# 處理表: 2636TW台驊控股
# 總進度: 17.4% (222/1276)
# 處理表: 4771TW望隼
# 總進度: 17.5% (223/1276)
# 總進度: 17.6% (224/1276)
# 處理表: 8163TW達方
# 總進度: 17.6% (225/1276)
# 處理表: 3652TW精聯
# 處理表: 2376TW技嘉總進度: 17.7% (226/1276)
#
# 總進度: 17.8% (227/1276)處理表: 6789TW采鈺
#
# 總進度: 17.9% (228/1276)處理表: 2114TW鑫永銓
#
# 處理表: 6438TW迅得總進度: 17.9% (229/1276)
#
# 總進度: 18.0% (230/1276)
# 處理表: 2904TW匯僑
# 處理表: 1731TW美吾華
# 總進度: 18.1% (231/1276)
# 總進度: 18.2% (232/1276)
# 處理表: 5906TW台南-KY
# 總進度: 18.3% (233/1276)處理表: 1515TW力山
#
# 處理表: 8162TW微矽電子-創
# 總進度: 18.3% (234/1276)
# 總進度: 18.4% (235/1276)
# 處理表: 1319TW東陽
# 處理表: 01007TTW總進度: 18.5% (236/1276)
#
# 處理表: 3062TW建漢
# 總進度: 18.6% (237/1276)
# 處理表: 00885TW總進度: 18.7% (238/1276)
#
# 處理表: 00666RTW
# 總進度: 18.7% (239/1276)
# 總進度: 18.8% (240/1276)處理表: 2637TW慧洋-KY
#
# 處理表: 9928TW中視
# 總進度: 18.9% (241/1276)
# 總進度: 19.0% (242/1276)處理表: 4766TW南寶
#
# 處理表: 2476TW鉅祥
# 總進度: 19.0% (243/1276)
# 處理表: 8201TW無敵
# 總進度: 19.1% (244/1276)
# 總進度: 19.2% (245/1276)
# 處理表: 2377TW微星
# 處理表: 6792TW詠業總進度: 19.3% (246/1276)
#
# 總進度: 19.4% (247/1276)
# 處理表: 2115TW六暉-KY
# 總進度: 19.4% (248/1276)
# 處理表: 6443TW元晶
# 總進度: 19.5% (249/1276)處理表: 2905TW三商
#
# 總進度: 19.6% (250/1276)處理表: 1732TW毛寶
#
# 處理表: 5907TW大洋-KY
# 總進度: 19.7% (251/1276)
# 處理表: 1516TW川飛總進度: 19.7% (252/1276)
#
# 總進度: 19.8% (253/1276)
# 處理表: 1321TW大洋
# 總進度: 19.9% (254/1276)處理表: 3661TW世芯-KY
#
# 總進度: 20.0% (255/1276)處理表: 6790TW永豐實
#
# 處理表: 01004TTW
# 總進度: 20.1% (256/1276)
# 處理表: 3090TW日電貿總進度: 20.1% (257/1276)
#
# 總進度: 20.2% (258/1276)
# 處理表: 6442TW光聖
# 處理表: 00891TW
# 總進度: 20.3% (259/1276)
# 總進度: 20.4% (260/1276)
# 處理表: 2906TW高林
# 總進度: 20.5% (261/1276)處理表: 00668TW
#
# 處理表: 2642TW宅配通總進度: 20.5% (262/1276)
#
# 處理表: 9931TW欣高
# 總進度: 20.6% (263/1276)
# 總進度: 20.7% (264/1276)
# 處理表: 2477TW美隆電
# 總進度: 20.8% (265/1276)
# 處理表: 2379TW瑞昱
# 處理表: 3092TW鴻碩
# 總進度: 20.8% (266/1276)
# 處理表: 2201TW裕隆
# 總進度: 20.9% (267/1276)
# 處理表: 1733TW五鼎
# 總進度: 21.0% (268/1276)
# 總進度: 21.1% (269/1276)處理表: 6024TW群益期
#
# 總進度: 21.2% (270/1276)
# 處理表: 9933TW中鼎
# 處理表: 1517TW利奇
# 總進度: 21.2% (271/1276)
# 總進度: 21.3% (272/1276)
# 處理表: 4904TW遠傳
# 處理表: 8210TW勤誠
# 總進度: 21.4% (273/1276)
# 處理表: 1323TW永裕
# 總進度: 21.5% (274/1276)
# 處理表: 3665TW貿聯-KY
# 總進度: 21.6% (275/1276)
# 總進度: 21.6% (276/1276)處理表: 01009TTW
#
# 處理表: 00892TW
# 總進度: 21.7% (277/1276)
# 處理表: 6108TW競國總進度: 21.8% (278/1276)
#
# 處理表: 00668KTW
# 總進度: 21.9% (279/1276)
# 處理表: 2645TW長榮航太
# 總進度: 21.9% (280/1276)
# 總進度: 22.0% (281/1276)處理表: 9935TW慶豐富
#
# 總進度: 22.1% (282/1276)處理表: 4807TW日成-KY
#
# 總進度: 22.2% (283/1276)
# 處理表: 2478TW大毅
# 處理表: 2380TW虹光總進度: 22.3% (284/1276)
#
# 處理表: 6794TW向榮生技-創總進度: 22.3% (285/1276)
#
# 處理表: 2204TW中華
# 總進度: 22.4% (286/1276)
# 處理表: 6446TW藥華藥總進度: 22.5% (287/1276)
#
# 總進度: 22.6% (288/1276)
# 處理表: 1734TW杏輝
# 總進度: 22.6% (289/1276)
# 處理表: 6005TW群益證
# 處理表: 1519TW華城總進度: 22.7% (290/1276)
#
# 總進度: 22.8% (291/1276)
# 處理表: 4906TW正文
# 處理表: 1324TW地球總進度: 22.9% (292/1276)
#
# 總進度: 23.0% (293/1276)處理表: 3669TW圓展
#
# 處理表: 01010TTW
# 總進度: 23.0% (294/1276)
# 總進度: 23.1% (295/1276)處理表: 3138TW耀登
#
# 處理表: 6449TW鈺邦
# 總進度: 23.2% (296/1276)
# 總進度: 23.3% (297/1276)
# 處理表: 00893TW
# 處理表: 2910TW統領
# 總進度: 23.4% (298/1276)
# 處理表: 00669RTW
# 總進度: 23.4% (299/1276)
# 處理表: 2646TW星宇航空總進度: 23.5% (300/1276)
#
# 總進度: 23.6% (301/1276)
# 處理表: 2480TW敦陽科
# 總進度: 23.7% (302/1276)
# 處理表: 8213TW志超
# 處理表: 2382TW廣達
# 總進度: 23.7% (303/1276)
# 總進度: 23.8% (304/1276)處理表: 6796TW晉弘
#
# 總進度: 23.9% (305/1276)
# 處理表: 3094TW聯傑
# 處理表: 2206TW三陽工業總進度: 24.0% (306/1276)
#
# 總進度: 24.1% (307/1276)
# 總進度: 24.1% (308/1276)
# 總進度: 24.2% (309/1276)
# 處理表: 2908TW特力
# 處理表: 1735TW日勝化
# 處理表: 1521TW大億
# 處理表: 8215TW明基材總進度: 24.3% (310/1276)
#
# 處理表: 1325TW恆大
# 總進度: 24.4% (311/1276)
# 總進度: 24.5% (312/1276)處理表: 3673TWTPK-KY
#
# 處理表: 020000TW總進度: 24.5% (313/1276)
#
# 總進度: 24.6% (314/1276)
# 處理表: 3130TW一零四
# 處理表: 6451TW訊芯-KY總進度: 24.7% (315/1276)
#
# 總進度: 24.8% (316/1276)
# 處理表: 00894TW
# 處理表: 00670LTW總進度: 24.8% (317/1276)
#
# 處理表: 2701TW萬企
# 總進度: 24.9% (318/1276)
# 處理表: 9937TW全國總進度: 25.0% (319/1276)
#
# 處理表: 2482TW連宇
# 總進度: 25.1% (320/1276)
# 處理表: 3679TW新至陞
# 處理表: 2385TW群光
# 總進度: 25.2% (321/1276)
# 總進度: 25.2% (322/1276)
# 處理表: 6799TW來頡
# 總進度: 25.3% (323/1276)
# 處理表: 2207TW和泰車
# 總進度: 25.4% (324/1276)
# 總進度: 25.5% (325/1276)處理表: 2912TW統一超
#
# 處理表: 1736TW喬山總進度: 25.5% (326/1276)
#
# 總進度: 25.6% (327/1276)
# 處理表: 6112TW邁達特
# 處理表: 1522TW堤維西
# 總進度: 25.7% (328/1276)
# 處理表: 4912TW聯德控股-KY
# 總進度: 25.8% (329/1276)
# 處理表: 2481TW強茂
# 總進度: 25.9% (330/1276)
# 處理表: 1326TW台化
# 總進度: 25.9% (331/1276)
# 總進度: 26.0% (332/1276)處理表: 020011TW
#
# 處理表: 00895TW總進度: 26.1% (333/1276)
#
# 總進度: 26.2% (334/1276)
# 處理表: 00671RTW
# 處理表: 2702TW華園總進度: 26.3% (335/1276)
#
# 總進度: 26.3% (336/1276)
# 處理表: 9934TW成霖
# 總進度: 26.4% (337/1276)
# 處理表: 4915TW致伸
# 處理表: 8222TW寶一
# 總進度: 26.5% (338/1276)
# 處理表: 2383TW台光電
# 總進度: 26.6% (339/1276)
# 處理表: 6805TW富世達
# 總進度: 26.6% (340/1276)
# 總進度: 26.7% (341/1276)處理表: 2208TW台船
#
# 總進度: 26.8% (342/1276)
# 處理表: 6456TWGIS-KY
# 處理表: 1737TW臺鹽總進度: 26.9% (343/1276)
#
# 處理表: 6115TW鎰勝
# 總進度: 27.0% (344/1276)
# 處理表: 1522ATW
# 總進度: 27.0% (345/1276)
# 總進度: 27.1% (346/1276)
# 處理表: 1337TW再生-KY
# 處理表: 3686TW達能
# 總進度: 27.2% (347/1276)
# 總進度: 27.3% (348/1276)
# 處理表: 020012TW
# 總進度: 27.4% (349/1276)處理表: 3150TW鈺寶-創
#
# 處理表: 00896TW總進度: 27.4% (350/1276)
#
# 總進度: 27.5% (351/1276)處理表: 2913TW農林
#
# 總進度: 27.6% (352/1276)處理表: 00673RTW
#
# 總進度: 27.7% (353/1276)
# 總進度: 27.7% (354/1276)
# 處理表: 2704TW國賓
# 處理表: 9938TW百和
# 處理表: 2483TW百容
# 總進度: 27.8% (355/1276)
# 處理表: 8249TW菱光
# 總進度: 27.9% (356/1276)
# 處理表: 2387TW精元
# 總進度: 28.0% (357/1276)
# 處理表: 6807TW峰源-KY
# 總進度: 28.1% (358/1276)
# 處理表: 3149TW正達
# 總進度: 28.1% (359/1276)
# 處理表: 2211TW長榮鋼
# 總進度: 28.2% (360/1276)
# 處理表: 6464TW台數科
# 總進度: 28.3% (361/1276)
# 總進度: 28.4% (362/1276)處理表: 1752TW南光
#
# 總進度: 28.4% (363/1276)處理表: 6116TW彩晶
#
# 處理表: 9939TW宏全
# 總進度: 28.5% (364/1276)
# 處理表: 1524TW耿鼎
# 總進度: 28.6% (365/1276)
# 總進度: 28.7% (366/1276)處理表: 4916TW事欣科
#
# 總進度: 28.8% (367/1276)處理表: 1338TW廣華-KY
#
# 處理表: 3694TW海華
# 總進度: 28.8% (368/1276)
# 處理表: 6830TW汎銓
# 總進度: 28.9% (369/1276)
# 總進度: 29.0% (370/1276)處理表: 020015TW
#
# 總進度: 29.1% (371/1276)
# 處理表: 3167TW大量
# 處理表: 00897TW總進度: 29.2% (372/1276)
#
# 總進度: 29.2% (373/1276)
# 處理表: 2911TW麗嬰房
# 處理表: 00674RTW總進度: 29.3% (374/1276)
#
# 處理表: 2705TW六福
# 總進度: 29.4% (375/1276)
# 總進度: 29.5% (376/1276)
# 處理表: 2484TW希華
# 處理表: 8261TW富鼎
# 總進度: 29.5% (377/1276)
# 總進度: 29.6% (378/1276)
# 處理表: 2388TW威盛
# 總進度: 29.7% (379/1276)處理表: 6806TW森崴能源
#
# 處理表: 3164TW景岳
# 總進度: 29.8% (380/1276)
# 處理表: 2227TW裕日車
# 總進度: 29.9% (381/1276)
# 處理表: 6472TW保瑞總進度: 29.9% (382/1276)
#
# 總進度: 30.0% (383/1276)
# 處理表: 1760TW寶齡富錦
# 處理表: 6117TW迎廣
# 總進度: 30.1% (384/1276)
# 總進度: 30.2% (385/1276)
# 處理表: 1525TW江申
# 處理表: 4927TW泰鼎-KY總進度: 30.3% (386/1276)
#
# 處理表: 1339TW昭輝
# 總進度: 30.3% (387/1276)
# 總進度: 30.4% (388/1276)
# 處理表: 3701TW大眾控
# 處理表: 020016TW總進度: 30.5% (389/1276)
#
# 處理表: 00898TW
# 總進度: 30.6% (390/1276)
# 處理表: 2915TW潤泰全
# 總進度: 30.6% (391/1276)
# 總進度: 30.7% (392/1276)
# 總進度: 30.8% (393/1276)
# 處理表: 00675LTW
# 處理表: 2706TW第一店
# 總進度: 30.9% (394/1276)
# 總進度: 31.0% (395/1276)
# 處理表: 9940TW信義
# 處理表: 4919TW新唐
# 總進度: 31.0% (396/1276)處理表: 2485TW兆赫
#
# 處理表: 8271TW宇瞻
# 總進度: 31.1% (397/1276)
# 處理表: 2390TW云辰總進度: 31.2% (398/1276)
#
# 總進度: 31.3% (399/1276)
# 處理表: 6834TW天二科技
# 總進度: 31.3% (400/1276)處理表: 3168TW眾福科
#
# 總進度: 31.4% (401/1276)
# 處理表: 2228TW劍麟
# 處理表: 6477TW安集總進度: 31.5% (402/1276)
#
# 總進度: 31.6% (403/1276)
# 處理表: 1762TW中化生
# 總進度: 31.7% (404/1276)處理表: 6120TW達運
#
# 總進度: 31.7% (405/1276)
# 處理表: 9941TW裕融
# 總進度: 31.8% (406/1276)處理表: 1526TW日馳
#
# 處理表: 1340TW勝悅-KY
# 總進度: 31.9% (407/1276)
# 總進度: 32.0% (408/1276)
# 處理表: 3705TW永信
# 總進度: 32.1% (409/1276)處理表: 020018TW
#
# 總進度: 32.1% (410/1276)處理表: 00899TW
#
# 總進度: 32.2% (411/1276)
# 處理表: 2923TW鼎固-KY
# 總進度: 32.3% (412/1276)處理表: 00676RTW
#
# 處理表: 2707TW晶華總進度: 32.4% (413/1276)
#
# 總進度: 32.4% (414/1276)
# 處理表: 2486TW一詮
# 總進度: 32.5% (415/1276)
# 處理表: 8367TW建新國際
# 處理表: 3704TW合勤控總進度: 32.6% (416/1276)
#
# 處理表: 2392TW正崴
# 總進度: 32.7% (417/1276)
# 處理表: 2231TW為升總進度: 32.8% (418/1276)
#
# 總進度: 32.8% (419/1276)處理表: 6505TW台塑化
#
# 處理表: 1773TW勝一
# 總進度: 32.9% (420/1276)
# 處理表: 6128TW上福
# 總進度: 33.0% (421/1276)
# 總進度: 33.1% (422/1276)
# 處理表: 1527TW鑽全
# 總進度: 33.2% (423/1276)
# 總進度: 33.2% (424/1276)
# 處理表: 4930TW燦星網
# 處理表: 8341TW日友
# 處理表: 1341TW富林-KY
# 總進度: 33.3% (425/1276)
# 總進度: 33.4% (426/1276)
# 總進度: 33.5% (427/1276)
# 總進度: 33.5% (428/1276)
# 處理表: 020019TW
# 處理表: 6491TW晶碩
# 處理表: 00900TW
# 處理表: 2939TW永邑-KY總進度: 33.6% (429/1276)
#
# 總進度: 33.7% (430/1276)
# 總進度: 33.8% (431/1276)
# 處理表: 00678TW
# 處理表: 2712TW遠雄來
# 處理表: 9941ATW
# 總進度: 33.9% (432/1276)
# 總進度: 33.9% (433/1276)處理表: 2489TW瑞軒
#
# 處理表: 8374TW羅昇
# 總進度: 34.0% (434/1276)
# 總進度: 34.1% (435/1276)
# 總進度: 34.2% (436/1276)
# 處理表: 3703TW欣陸
# 處理表: 2393TW億光
# 處理表: 6854TW錼創科技-KY創總進度: 34.2% (437/1276)
#
# 處理表: 2233TW宇隆
# 總進度: 34.3% (438/1276)
# 處理表: 6504TW南六
# 總進度: 34.4% (439/1276)
# 總進度: 34.5% (440/1276)處理表: 2929TW淘帝-KY
#
# 總進度: 34.6% (441/1276)
# 總進度: 34.6% (442/1276)
# 處理表: 1776TW展宇
# 處理表: 6133TW金橋
# 總進度: 34.7% (443/1276)
# 處理表: 1528TW恩德
# 總進度: 34.8% (444/1276)
# 處理表: 4934TW太極
# 處理表: 2491TW吉祥全總進度: 34.9% (445/1276)
#
# 總進度: 35.0% (446/1276)
# 總進度: 35.0% (447/1276)
# 處理表: 1342TW八貫
# 處理表: 3702TW大聯大
# 處理表: 6835TW圓裕總進度: 35.1% (448/1276)
#
# 處理表: 02001LTW總進度: 35.2% (449/1276)
#
# 處理表: 3189TW景碩總進度: 35.3% (450/1276)
#
# 總進度: 35.3% (451/1276)
# 總進度: 35.4% (452/1276)
# 總進度: 35.5% (453/1276)
# 處理表: 00901TW
# 處理表: 00680LTW
# 處理表: 2722TW夏都
# 總進度: 35.6% (454/1276)處理表: 9942TW茂順
#
# 處理表: 2488TW漢平
# 總進度: 35.7% (455/1276)
# 處理表: 2395TW研華總進度: 35.7% (456/1276)
#
# 處理表: 6838TW台新藥總進度: 35.8% (457/1276)
#
# 總進度: 35.9% (458/1276)
# 處理表: 2236TW百達-KY
# 總進度: 36.0% (459/1276)
# 總進度: 36.1% (460/1276)
# 處理表: 1783TW和康生
# 總進度: 36.1% (461/1276)
# 處理表: 6139TW亞翔
# 處理表: 1529TW樂事綠能
# 總進度: 36.2% (462/1276)
# 處理表: 4942TW嘉彰
# 總進度: 36.3% (463/1276)處理表: 8404TW百和興業-KY
#
# 總進度: 36.4% (464/1276)處理表: 1402TW遠東新
#
# 處理表: 3706TW神達
# 總進度: 36.4% (465/1276)
# 處理表: 6861TW睿生光電總進度: 36.5% (466/1276)
#
# 總進度: 36.6% (467/1276)
# 處理表: 02001RTW
# 處理表: 3229TW晟鈦
# 總進度: 36.7% (468/1276)
# 總進度: 36.8% (469/1276)
# 處理表: 00902TW
# 總進度: 36.8% (470/1276)
# 處理表: 2945TW三商家購
# 處理表: 00681RTW總進度: 36.9% (471/1276)
#
# 處理表: 2723TW美食-KY
# 總進度: 37.0% (472/1276)
# 處理表: 9943TW好樂迪
# 總進度: 37.1% (473/1276)
# 處理表: 4935TW茂林-KY總進度: 37.1% (474/1276)
#
# 處理表: 2397TW友通總進度: 37.2% (475/1276)
#
# 總進度: 37.3% (476/1276)
# 處理表: 6862TW三集瑞-KY
# 處理表: 3231TW緯創總進度: 37.4% (477/1276)
#
# 處理表: 2239TW英利-KY
# 總進度: 37.5% (478/1276)
# 總進度: 37.5% (479/1276)
# 處理表: 6525TW捷敏-KY
# 總進度: 37.6% (480/1276)
# 處理表: 1786TW科妍
# 處理表: 6136TW富爾特
# 總進度: 37.7% (481/1276)
# 處理表: 9946TW三發地產總進度: 37.8% (482/1276)
#
# 總進度: 37.9% (483/1276)
# 處理表: 1530TW亞崴
# 總進度: 37.9% (484/1276)處理表: 4943TW康控-KY
#
# 處理表: 1409TW新纖
# 總進度: 38.0% (485/1276)
# 總進度: 38.1% (486/1276)
# 處理表: 02001STW
# 處理表: 3209TW全科總進度: 38.2% (487/1276)
#
# 總進度: 38.2% (488/1276)
# 處理表: 6526TW達發
# 處理表: 00903TW
# 總進度: 38.3% (489/1276)
# 處理表: 3003TW健和興總進度: 38.4% (490/1276)
#
# 總進度: 38.5% (491/1276)
# 處理表: 00682UTW
# 處理表: 2727TW王品總進度: 38.6% (492/1276)
#
# 總進度: 38.6% (493/1276)
# 處理表: 4938TW和碩
# 處理表: 2492TW華新科
# 總進度: 38.7% (494/1276)
# 總進度: 38.8% (495/1276)處理表: 8411TW福貞-KY
#
# ...
#
# 處理表: 6949TW沛爾生醫-創
# 總進度: 66.1% (844/1276)
# 處理表: 1110TW東泥
# 總進度: 66.2% (845/1276)
# 總進度: 66.3% (846/1276)處理表: 3437TW榮創
#
# 總進度: 66.4% (847/1276)
# 處理表: 00924TW
# 處理表: 3025TW星通
# 總進度: 66.5% (848/1276)
# 總進度: 66.5% (849/1276)
# 處理表: 00711BTW
# 處理表: 2850TW新產
# 總進度: 66.6% (850/1276)
# 處理表: 5225TW東科-KY總進度: 66.7% (851/1276)
#
# 處理表: 00625KTW
# 總進度: 66.8% (852/1276)
# 總進度: 66.8% (853/1276)
# 處理表: 2530TW華建
# 總進度: 66.9% (854/1276)
# 處理表: 4426TW利勤
# 總進度: 67.0% (855/1276)處理表: 2426TW鼎元
#
# 處理表: 3432TW台端
# 總進度: 67.1% (856/1276)
# 處理表: 2328TW廣宇總進度: 67.2% (857/1276)
#
# 總進度: 67.2% (858/1276)
# 處理表: 6605TW帝寶
# 總進度: 67.3% (859/1276)
# 處理表: 2008TW高興昌
# 總進度: 67.4% (860/1276)處理表: 6205TW詮欣
#
# 處理表: 2851TW中再保
# 總進度: 67.5% (861/1276)
# 處理表: 1597TW直得總進度: 67.6% (862/1276)
#
# 總進度: 67.6% (863/1276)
# 處理表: 1444TW力麗
# 總進度: 67.7% (864/1276)
# 處理表: 1201TW味全
# 總進度: 67.8% (865/1276)
# 處理表: 3443TW創意
# 處理表: 6606TW建德工業
# 總進度: 67.9% (866/1276)
# 處理表: 00925TW
# 總進度: 67.9% (867/1276)
# 處理表: 3027TW盛達總進度: 68.0% (868/1276)
#
# 總進度: 68.1% (869/1276)
# 處理表: 00712TW
# 處理表: 00631LTW
# 總進度: 68.2% (870/1276)
# 處理表: 2534TW宏盛總進度: 68.3% (871/1276)
#
# 總進度: 68.3% (872/1276)
# 處理表: 8926TW台汽電
# 處理表: 2427TW三商電總進度: 68.4% (873/1276)
#
# 處理表: 6952TW大武山總進度: 68.5% (874/1276)
#
# 處理表: 2329TW華泰
# 總進度: 68.6% (875/1276)
# 總進度: 68.7% (876/1276)
# 處理表: 3028TW增你強
# 總進度: 68.7% (877/1276)處理表: 2009TW第一銅
#
# 總進度: 68.8% (878/1276)
# 處理表: 6202TW盛群
# 處理表: 1598TW岱宇
# 總進度: 68.9% (879/1276)
# 總進度: 69.0% (880/1276)處理表: 5234TW達興材料
#
# 處理表: 1445TW大宇
# 總進度: 69.0% (881/1276)
# 處理表: 4438TW廣越總進度: 69.1% (882/1276)
#
# 總進度: 69.2% (883/1276)
# 總進度: 69.3% (884/1276)
# 處理表: 1203TW味王
# 處理表: 3447TW展達
# 處理表: 00926TW
# 總進度: 69.4% (885/1276)
# 總進度: 69.4% (886/1276)
# 處理表: 3026TW禾伸堂
# 總進度: 69.5% (887/1276)
# 總進度: 69.6% (888/1276)
# 處理表: 00713TW
# 處理表: 2852TW第一保
# 總進度: 69.7% (889/1276)
# 總進度: 69.7% (890/1276)
# 處理表: 00632RTW
# 處理表: 2535TW達欣工
# 總進度: 69.8% (891/1276)處理表: 8940TW新天地
#
# 總進度: 69.9% (892/1276)
# 處理表: 2428TW興勤
# 總進度: 70.0% (893/1276)
# 處理表: 6951TW青新-創
# 總進度: 70.1% (894/1276)
# 總進度: 70.1% (895/1276)
# 處理表: 2331TW精英
# 處理表: 6625TW必應
# 處理表: 2010TW春源總進度: 70.2% (896/1276)
#
# 處理表: 6206TW飛捷
# 總進度: 70.3% (897/1276)
# 總進度: 70.4% (898/1276)處理表: 1603TW華電
#
# 總進度: 70.5% (899/1276)處理表: 5243TW乙盛-KY
#
# 總進度: 70.5% (900/1276)
# 處理表: 1446TW宏和
# 處理表: 4439TW冠星-KY總進度: 70.6% (901/1276)
# 處理表: 1210TW大成
#
# 總進度: 70.7% (902/1276)
# 處理表: 6641TW基士德-KY
# 總進度: 70.8% (903/1276)
# 總進度: 70.8% (904/1276)處理表: 00929TW
#
# 總進度: 70.9% (905/1276)
# 處理表: 00714TW
# 處理表: 2855TW統一證總進度: 71.0% (906/1276)
#
# 總進度: 71.1% (907/1276)
# 處理表: 00633LTW
# 總進度: 71.2% (908/1276)處理表: 2536TW宏普
#
# 總進度: 71.2% (909/1276)
# 處理表: 8996TW高力
# 總進度: 71.3% (910/1276)
# 處理表: 2429TW銘旺科
# 處理表: 6955TW邦睿生技-創
# 總進度: 71.4% (911/1276)
# 總進度: 71.5% (912/1276)處理表: 2332TW友訊
#
# 處理表: 6645TW金萬林-創
# 總進度: 71.6% (913/1276)
# 處理表: 2012TW春雨
# 總進度: 71.6% (914/1276)
# 總進度: 71.7% (915/1276)
# 處理表: 6209TW今國光
# 處理表: 1604TW聲寶總進度: 71.8% (916/1276)
#
# 總進度: 71.9% (917/1276)
# 總進度: 71.9% (918/1276)
# 總進度: 72.0% (919/1276)
# 處理表: 5244TW弘凱
# 處理表: 9103TW美德醫療-DR
# 處理表: 1447TW力鵬
# 總進度: 72.1% (920/1276)
# 處理表: 4526TW東台
# 總進度: 72.2% (921/1276)
# 總進度: 72.3% (922/1276)
# 處理表: 1213TW大飲
# 處理表: 3450TW聯鈞
# 總進度: 72.3% (923/1276)處理表: 00927TW
#
# 總進度: 72.4% (924/1276)
# 處理表: 3030TW德律
# 總進度: 72.5% (925/1276)處理表: 00715LTW
#
# 處理表: 2867TW三商壽
# 總進度: 72.6% (926/1276)
# 處理表: 00634RTW
# 總進度: 72.6% (927/1276)
# 處理表: 2537TW聯上發總進度: 72.7% (928/1276)
#
# 總進度: 72.8% (929/1276)
# 處理表: 910322TW康師傅-DR
# 總進度: 72.9% (930/1276)
# 處理表: 4440TW宜新實業
# 處理表: 2430TW燦坤總進度: 73.0% (931/1276)
#
# 總進度: 73.0% (932/1276)
# 處理表: 6957TW裕慶-KY
# 處理表: 3454TW晶睿總進度: 73.1% (933/1276)
#
# 總進度: 73.2% (934/1276)處理表: 2337TW旺宏
#
# 總進度: 73.3% (935/1276)處理表: 3029TW零壹
#
# 總進度: 73.4% (936/1276)
# 處理表: 2013TW中鋼構
# 總進度: 73.4% (937/1276)
# 處理表: 6213TW聯茂
# 總進度: 73.5% (938/1276)處理表: 1605TW華新
#
# 總進度: 73.6% (939/1276)
# 處理表: 5258TW虹堡
# 總進度: 73.7% (940/1276)處理表: 1449TW佳和
#
# 總進度: 73.7% (941/1276)處理表: 1216TW統一
#
# 總進度: 73.8% (942/1276)處理表: 00930TW
#
# 總進度: 73.9% (943/1276)
# 處理表: 6215TW和椿
# 總進度: 74.0% (944/1276)
# 處理表: 00717TW
# 處理表: 2880TW華南金總進度: 74.1% (945/1276)
#
# 總進度: 74.1% (946/1276)
# 總進度: 74.2% (947/1276)
# 處理表: 00635UTW
# 處理表: 2538TW基泰
# 處理表: 2431TW聯昌總進度: 74.3% (948/1276)
#
# 總進度: 74.4% (949/1276)處理表: 6958TW日盛台駿
#
# 總進度: 74.5% (950/1276)
# 處理表: 2338TW光罩
# 總進度: 74.5% (951/1276)
# 處理表: 6655TW科定
# 總進度: 74.6% (952/1276)
# 處理表: 2014TW中鴻
# 總進度: 74.7% (953/1276)
# 處理表: 1608TW華榮
# 總進度: 74.8% (954/1276)處理表: 5269TW祥碩
#
# 總進度: 74.8% (955/1276)
# 處理表: 1451TW年興
# 處理表: 4532TW瑞智總進度: 74.9% (956/1276)
#
# 處理表: 1215TW卜蜂
# 總進度: 75.0% (957/1276)
# 總進度: 75.1% (958/1276)處理表: 3481TW群創
#
# 總進度: 75.2% (959/1276)
# 處理表: 6657TW華安
# 總進度: 75.2% (960/1276)
# 處理表: 00932TW
# 處理表: 3031TW佰鴻
# 總進度: 75.3% (961/1276)
# 總進度: 75.4% (962/1276)處理表: 00728TW
#
# 處理表: 2881TW富邦金
# 總進度: 75.5% (963/1276)
# 處理表: 5283TW禾聯碩總進度: 75.5% (964/1276)
#
# 處理表: 00636TW
# 總進度: 75.6% (965/1276)
# 總進度: 75.7% (966/1276)處理表: 2539TW櫻花建
#
# 總進度: 75.8% (967/1276)
# 處理表: 910861TW神州-DR
# 處理表: 2432TW倚天酷碁-創總進度: 75.9% (968/1276)
# 總進度: 75.9% (969/1276)
#
# 處理表: 6969TW成信實業*-創
# 處理表: 2340TW台亞總進度: 76.0% (970/1276)
#
# 總進度: 76.1% (971/1276)
# 處理表: 3033TW威健
# 處理表: 2015TW豐興
# 總進度: 76.2% (972/1276)
# 處理表: 6214TW精誠總進度: 76.3% (973/1276)
#
# 處理表: 2881ATW
# 總進度: 76.3% (974/1276)
# 處理表: 1609TW大亞總進度: 76.4% (975/1276)
#
# 處理表: 9105TW泰金寶-DR總進度: 76.5% (976/1276)
#
# 總進度: 76.6% (977/1276)
# 處理表: 1452TW宏益
# 總進度: 76.6% (978/1276)
# 處理表: 4540TW全球傳動
# 總進度: 76.7% (979/1276)
# 總進度: 76.8% (980/1276)
# 處理表: 6962TWITH-KY
# 總進度: 76.9% (981/1276)
# 處理表: 1217TW愛之味
# 處理表: 3494TW誠研
# 總進度: 77.0% (982/1276)處理表: 6666TW羅麗芬-KY
#
# 總進度: 77.0% (983/1276)
# 處理表: 00935TW
# 總進度: 77.1% (984/1276)處理表: 3032TW偉訓
#
# 處理表: 00730TW
# 總進度: 77.2% (985/1276)
# 總進度: 77.3% (986/1276)處理表: 00636KTW
#
# 處理表: 2540TW愛山林
# 總進度: 77.4% (987/1276)
# 處理表: 4536TW拓凱
# 總進度: 77.4% (988/1276)
# 總進度: 77.5% (989/1276)處理表: 2433TW互盛電
#
# 處理表: 2342TW茂矽總進度: 77.6% (990/1276)
#
# 總進度: 77.7% (991/1276)處理表: 6658TW聯策
#
# 總進度: 77.7% (992/1276)
# 處理表: 2017TW官田鋼
# 總進度: 77.8% (993/1276)
# 處理表: 6216TW居易
# 處理表: 1611TW中電總進度: 77.9% (994/1276)
#
# 總進度: 78.0% (995/1276)
# 處理表: 5284TWjpp-KY
# 總進度: 78.1% (996/1276)處理表: 1453TW大將
#
# 總進度: 78.1% (997/1276)
# 總進度: 78.2% (998/1276)
# 處理表: 1218TW泰山
# 處理表: 3501TW維熹
# 處理表: 00934TW總進度: 78.3% (999/1276)
#
# 處理表: 00731TW總進度: 78.4% (1000/1276)
#
# 處理表: 2881BTW
# 總進度: 78.4% (1001/1276)
# 處理表: 00637LTW
# 總進度: 78.5% (1002/1276)
# 處理表: 2542TW興富發總進度: 78.6% (1003/1276)
#
# 總進度: 78.7% (1004/1276)
# 處理表: 9110TW越南控-DR
# 總進度: 78.8% (1005/1276)處理表: 2434TW統懋
#
# 總進度: 78.8% (1006/1276)處理表: 6988TW威力暘-創
#
# 處理表: 2344TW華邦電
# 總進度: 78.9% (1007/1276)
# 總進度: 79.0% (1008/1276)
# 處理表: 2020TW美亞
# 處理表: 6224TW聚鼎總進度: 79.1% (1009/1276)
#
# 處理表: 2881CTW
# 總進度: 79.2% (1010/1276)
# 處理表: 1612TW宏泰總進度: 79.2% (1011/1276)
#
# 總進度: 79.3% (1012/1276)處理表: 5285TW界霖
#
# 總進度: 79.4% (1013/1276)
# 處理表: 1454TW台富
# 總進度: 79.5% (1014/1276)
# 總進度: 79.5% (1015/1276)
# 處理表: 4551TW智伸科
# 處理表: 1219TW福壽
# 處理表: 3504TW揚明光總進度: 79.6% (1016/1276)
#
# 總進度: 79.7% (1017/1276)處理表: 00938TW
#
# 處理表: 3035TW智原總進度: 79.8% (1018/1276)
#
# 處理表: 6226TW光鼎
# 總進度: 79.9% (1019/1276)
# 處理表: 00733TW總進度: 79.9% (1020/1276)
#
# 處理表: 00638RTW
# 總進度: 80.0% (1021/1276)
# 總進度: 80.1% (1022/1276)處理表: 2543TW皇昌
#
# 處理表: 911608TW明輝-DR總進度: 80.2% (1023/1276)
#
# 總進度: 80.3% (1024/1276)
# 處理表: 4545TW銘鈺
# 總進度: 80.3% (1025/1276)
# 處理表: 2436TW偉詮電
# 處理表: 6994TW富威電力總進度: 80.4% (1026/1276)
#
# 總進度: 80.5% (1027/1276)處理表: 3515TW華擎
#
# 總進度: 80.6% (1028/1276)
# 處理表: 2345TW智邦
# 總進度: 80.6% (1029/1276)
# 總進度: 80.7% (1030/1276)
# 處理表: 6668TW中揚光
# 處理表: 3034TW聯詠
# 總進度: 80.8% (1031/1276)處理表: 2022TW聚亨
#
# 總進度: 80.9% (1032/1276)
# 處理表: 1614TW三洋電
# 處理表: 5288TW豐祥-KY總進度: 81.0% (1033/1276)
#
# 處理表: 911622TW泰聚亨-DR
# 總進度: 81.0% (1034/1276)
# 處理表: 1455TW集盛總進度: 81.1% (1035/1276)
#
# 處理表: 1220TW台榮
# 總進度: 81.2% (1036/1276)
# 總進度: 81.3% (1037/1276)處理表: 00936TW
#
# 總進度: 81.3% (1038/1276)
# 處理表: 6230TW尼得科超眾
# 處理表: 00735TW總進度: 81.4% (1039/1276)
#
# 總進度: 81.5% (1040/1276)
# 處理表: 2882ATW
# 處理表: 5306TW桂盟
# 總進度: 81.6% (1041/1276)
# 處理表: 00639TW總進度: 81.7% (1042/1276)
#
# 總進度: 81.7% (1043/1276)處理表: 2545TW皇翔
#
# 總進度: 81.8% (1044/1276)
# 處理表: 2438TW翔耀
# 處理表: 7705TW三商餐飲
# 總進度: 81.9% (1045/1276)
# 處理表: 2347TW聯強
# 總進度: 82.0% (1046/1276)
# 處理表: 6672TW騰輝電子-KY總進度: 82.1% (1047/1276)
#
# 總進度: 82.1% (1048/1276)
# 總進度: 82.2% (1049/1276)
# 處理表: 2023TW燁輝
# 處理表: 2882TW國泰金
# 處理表: 1615TW大山總進度: 82.3% (1050/1276)
#
# 總進度: 82.4% (1051/1276)
# 總進度: 82.4% (1052/1276)
# 總進度: 82.5% (1053/1276)
# 處理表: 1456TW怡華
# 處理表: 4552TW力達-KY
# 處理表: 1225TW福懋油
# 處理表: 3528TW安馳總進度: 82.6% (1054/1276)
#
# 處理表: 6670TW復盛應用
# 總進度: 82.7% (1055/1276)
# 總進度: 82.8% (1056/1276)處理表: 00939TW
#
# 總進度: 82.8% (1057/1276)
# 處理表: 3036TW文曄
# 處理表: 00736TW
# 總進度: 82.9% (1058/1276)
# 處理表: 00640LTW
# 總進度: 83.0% (1059/1276)
# 總進度: 83.1% (1060/1276)處理表: 2546TW根基
#
# 總進度: 83.2% (1061/1276)
# 處理表: 911868TW同方友友-DR
# 處理表: 2439TW美律總進度: 83.2% (1062/1276)
#
# 處理表: 7722TWLINEPAY
# 總進度: 83.3% (1063/1276)
# 總進度: 83.4% (1064/1276)
# 處理表: 1227TW佳格
# 處理表: 3518TW柏騰
# 總進度: 83.5% (1065/1276)
# 總進度: 83.5% (1066/1276)
# 處理表: 2348TW海悅
# 處理表: 6671TW三能-KY
# 總進度: 83.6% (1067/1276)
# 總進度: 83.7% (1068/1276)處理表: 3036ATW
#
# 總進度: 83.8% (1069/1276)
# 總進度: 83.9% (1070/1276)
# 處理表: 2024TW志聯
# 處理表: 6225TW天瀚
# 總進度: 83.9% (1071/1276)處理表: 1616TW億泰
#
# 總進度: 84.0% (1072/1276)
# 處理表: 5292TW華懋
# 處理表: 9136TW巨騰-DR
# 總進度: 84.1% (1073/1276)
# 處理表: 1457TW宜進總進度: 84.2% (1074/1276)
#
# 處理表: 4555TW氣立
# 總進度: 84.2% (1075/1276)
# 總進度: 84.3% (1076/1276)
# 總進度: 84.4% (1077/1276)
# 總進度: 84.5% (1078/1276)
# 總進度: 84.6% (1079/1276)
# 總進度: 84.6% (1080/1276)
# 總進度: 84.7% (1081/1276)
# 處理表: 6674TW鋐寶科技
# 處理表: 00940TW
# 處理表: 00737TW
# 處理表: 2882BTW
# 處理表: 5388TW中磊
# 處理表: 00641RTW
# 總進度: 84.8% (1082/1276)處理表: 2547TW日勝生
#
# 總進度: 84.9% (1083/1276)
# 處理表: 4557TW永新-KY
# 處理表: 2440TW太空梭總進度: 85.0% (1084/1276)
#
# 總進度: 85.0% (1085/1276)
# 處理表: 7732TW金興精密
# 總進度: 85.1% (1086/1276)處理表: 2348ATW
#
# 總進度: 85.2% (1087/1276)
# 處理表: 6669TW緯穎
# 處理表: 2027TW大成鋼
# 總進度: 85.3% (1088/1276)
# 總進度: 85.3% (1089/1276)
# 處理表: 6235TW華孚
# 處理表: 1617TW榮星
# 總進度: 85.4% (1090/1276)
# 總進度: 85.5% (1091/1276)處理表: 1459TW聯發
#
# 處理表: 4560TW強信-KY總進度: 85.6% (1092/1276)
#
# 總進度: 85.7% (1093/1276)處理表: 1229TW聯華
#
# 總進度: 85.7% (1094/1276)
# 總進度: 85.8% (1095/1276)
# 總進度: 85.9% (1096/1276)
# 處理表: 3530TW晶相光
# 處理表: 00943TW
# 處理表: 3037TW欣興
# 總進度: 86.0% (1097/1276)處理表: 00738UTW
#
# 總進度: 86.1% (1098/1276)
# 處理表: 2883BTW
# 總進度: 86.1% (1099/1276)
# 處理表: 5434TW崇越
# 總進度: 86.2% (1100/1276)處理表: 00642UTW
#
# 總進度: 86.3% (1101/1276)處理表: 2548TW華固
#
# 總進度: 86.4% (1102/1276)處理表: 9802TW鈺齊-KY
#
# 總進度: 86.4% (1103/1276)
# 處理表: 2442TW新美齊
# 處理表: 8016TW矽創總進度: 86.5% (1104/1276)
#
# 處理表: 2349TW錸德
# 總進度: 86.6% (1105/1276)
# 總進度: 86.7% (1106/1276)
# 處理表: 2028TW威致
# 總進度: 86.8% (1107/1276)處理表: 6239TW力成
#
# 總進度: 86.8% (1108/1276)
# 處理表: 2884TW玉山金
# 處理表: 1618TW合機
# 總進度: 86.9% (1109/1276)
# 處理表: 1460TW宏遠總進度: 87.0% (1110/1276)
#
# 處理表: 2441TW超豐
# 總進度: 87.1% (1111/1276)
# 總進度: 87.1% (1112/1276)
# 處理表: 8011TW台通
# 處理表: 1231TW聯華食
# 總進度: 87.2% (1113/1276)
# 處理表: 3533TW嘉澤
# 總進度: 87.3% (1114/1276)
# 處理表: 00941TW總進度: 87.4% (1115/1276)
#
# 總進度: 87.5% (1116/1276)
# 處理表: 3038TW全台
# 總進度: 87.5% (1117/1276)
# 處理表: 00739TW
# 總進度: 87.6% (1118/1276)處理表: 2883TW凱基金
#
# 處理表: 00643TW
# 總進度: 87.7% (1119/1276)
# 總進度: 87.8% (1120/1276)
# 處理表: 2597TW潤弘
# 總進度: 87.9% (1121/1276)
# 處理表: 9902TW台火
# 處理表: 2444TW兆勁
# 總進度: 87.9% (1122/1276)
# 總進度: 88.0% (1123/1276)
# 總進度: 88.1% (1124/1276)
# 處理表: 8021TW尖點
# 處理表: 3532TW台勝科
# 處理表: 2351TW順德
# 總進度: 88.2% (1125/1276)
# 總進度: 88.2% (1126/1276)
# 處理表: 3040TW遠見
# 總進度: 88.3% (1127/1276)
# 處理表: 2029TW盛餘
# 處理表: 6243TW迅杰總進度: 88.4% (1128/1276)
#
# 總進度: 88.5% (1129/1276)
# 總進度: 88.6% (1130/1276)
# 處理表: 1626TW艾美特-KY
# 處理表: 5469TW瀚宇博
# 總進度: 88.6% (1131/1276)
# 總進度: 88.7% (1132/1276)
# 處理表: 1463TW強盛新
# 處理表: 4562TW穎漢
# 處理表: 1232TW大統益總進度: 88.8% (1133/1276)
#
# 處理表: 3545TW敦泰總進度: 88.9% (1134/1276)
#
# 處理表: 00944TW
# 總進度: 88.9% (1135/1276)
# 處理表: 00752TW總進度: 89.0% (1136/1276)
#
# 處理表: 00643KTW
# 處理表: 2601TW益航
# 總進度: 89.1% (1137/1276)
# 總進度: 89.2% (1138/1276)
# 處理表: 912000TW晨訊科-DR
# 總進度: 89.3% (1139/1276)
# 處理表: 4564TW元翎
# 總進度: 89.3% (1140/1276)
# 處理表: 3535TW晶彩科總進度: 89.4% (1141/1276)
#
# 總進度: 89.5% (1142/1276)
# 處理表: 2352TW佳世達
# 總進度: 89.6% (1143/1276)
# 處理表: 6689TW伊雲谷
# 總進度: 89.7% (1144/1276)
# 處理表: 2030TW彰源
# 總進度: 89.7% (1145/1276)處理表: 6257TW矽格
# 處理表: 1702TW南僑
#
# 總進度: 89.8% (1146/1276)
# 總進度: 89.9% (1147/1276)
# 處理表: 5471TW松翰
# 總進度: 90.0% (1148/1276)
# 總進度: 90.0% (1149/1276)
# 處理表: 1464TW得力
# 處理表: 1233TW天仁
# 總進度: 90.1% (1150/1276)處理表: 6695TW芯鼎
#
# 處理表: 00945BTW
# 總進度: 90.2% (1151/1276)
# 總進度: 90.3% (1152/1276)
# 總進度: 90.4% (1153/1276)
# 總進度: 90.4% (1154/1276)
# 處理表: 3041TW揚智
# 處理表: 00753LTW
# 處理表: 2885TW元大金
# 總進度: 90.5% (1155/1276)
# 處理表: 00645TW
# 總進度: 90.6% (1156/1276)
# 處理表: 2603TW長榮
# 處理表: 9904TW寶成
# 總進度: 90.7% (1157/1276)
# 總進度: 90.8% (1158/1276)
# 處理表: 2449TW京元電子
# 處理表: 8028TW昇陽半導體總進度: 90.8% (1159/1276)
#
# 總進度: 90.9% (1160/1276)
# 處理表: 3543TW州巧
# 處理表: 2353TW宏碁總進度: 91.0% (1161/1276)
#
# 處理表: 6691TW洋基工程
# 總進度: 91.1% (1162/1276)
# 總進度: 91.1% (1163/1276)
# 處理表: 2031TW新光鋼
# 總進度: 91.2% (1164/1276)
# 處理表: 6269TW台郡
# 處理表: 1707TW葡萄王總進度: 91.3% (1165/1276)
# 總進度: 91.4% (1166/1276)
# 處理表: 5484TW慧友
#
# 總進度: 91.5% (1167/1276)
# 處理表: 1465TW偉全
# 總進度: 91.5% (1168/1276)
# 處理表: 4566TW時碩工業
# 總進度: 91.6% (1169/1276)
# 處理表: 8033TW雷虎
# 總進度: 91.7% (1170/1276)
# 處理表: 1234TW黑松
# 總進度: 91.8% (1171/1276)處理表: 00947TW
#
# 總進度: 91.8% (1172/1276)
# 處理表: 3042TW晶技
# 總進度: 91.9% (1173/1276)處理表: 00757TW
#
# 總進度: 92.0% (1174/1276)
# 處理表: 2886TW兆豐金
# 處理表: 5515TW建國
# 總進度: 92.1% (1175/1276)
# 總進度: 92.2% (1176/1276)
# 處理表: 00646TW
# 總進度: 92.2% (1177/1276)處理表: 2605TW新興
#
# 總進度: 92.3% (1178/1276)處理表: 9908TW大台北
#
# 總進度: 92.4% (1179/1276)處理表: 2450TW神腦
#
# 總進度: 92.5% (1180/1276)
# 處理表: 2354TW鴻準
# 處理表: 2032TW新鋼
# 總進度: 92.6% (1181/1276)
# 處理表: 6271TW同欣電總進度: 92.6% (1182/1276)
#
# 處理表: 1708TW東鹼
# 總進度: 92.7% (1183/1276)
# 總進度: 92.8% (1184/1276)處理表: 5519TW隆大
#
# 總進度: 92.9% (1185/1276)處理表: 00647LTW
#
# 總進度: 92.9% (1186/1276)
# 總進度: 93.0% (1187/1276)
# 處理表: 1466TW聚隆
# 總進度: 93.1% (1188/1276)
# 處理表: 4571TW鈞興-KY
# 處理表: 1235TW興泰
# 總進度: 93.2% (1189/1276)
# 處理表: 00949TW
# 處理表: 3044TW健鼎
# 總進度: 93.3% (1190/1276)
# 總進度: 93.3% (1191/1276)處理表: 00762TW
#
# 總進度: 93.4% (1192/1276)
# 總進度: 93.5% (1193/1276)
# 處理表: 2887TW台新金
# 處理表: 2606TW裕民
# 處理表: 9905TW大華
# 總進度: 93.6% (1194/1276)
# 總進度: 93.7% (1195/1276)處理表: 2451TW創見
#
# 總進度: 93.7% (1196/1276)
# 處理表: 8039TW台虹
# 處理表: 2355TW敬鵬總進度: 93.8% (1197/1276)
#
# 總進度: 93.9% (1198/1276)
# 處理表: 6706TW惠特
# 處理表: 3045TW台灣大
# 總進度: 94.0% (1199/1276)
# 總進度: 94.0% (1200/1276)處理表: 2033TW佳大
#
# 總進度: 94.1% (1201/1276)處理表: 6277TW宏正
#
# 處理表: 1709TW和益
# 總進度: 94.2% (1202/1276)
# 處理表: 1467TW南緯總進度: 94.3% (1203/1276)
#
# 總進度: 94.4% (1204/1276)處理表: 4572TW駐龍
#
# 處理表: 1236TW宏亞總進度: 94.4% (1205/1276)
#
# 總進度: 94.5% (1206/1276)
# 總進度: 94.6% (1207/1276)
# 處理表: 3557TW嘉威
# 總進度: 94.7% (1208/1276)
# 處理表: 6698TW旭暉應材
# 處理表: 00946TW
# 處理表: 3043TW科風總進度: 94.7% (1209/1276)
#
# 總進度: 94.8% (1210/1276)
# 處理表: 6281TW全國電
# 總進度: 94.9% (1211/1276)
# 總進度: 95.0% (1212/1276)
# 處理表: 00763UTW
# 總進度: 95.1% (1213/1276)
# 處理表: 2887FTW
# 處理表: 00648RTW
# 處理表: 2608TW嘉里大榮總進度: 95.1% (1214/1276)
#
# 總進度: 95.2% (1215/1276)
# 處理表: 9906TW欣巴巴
# 處理表: 4569TW六方科-KY總進度: 95.3% (1216/1276)
#
# 處理表: 2453TW凌群
# 總進度: 95.4% (1217/1276)
# 總進度: 95.5% (1218/1276)
# 處理表: 8045TW達運光電
# 總進度: 95.5% (1219/1276)處理表: 3550TW聯穎
#
# 總進度: 95.6% (1220/1276)
# 處理表: 2356TW英業達
# 處理表: 2034TW允強總進度: 95.7% (1221/1276)
#
# 總進度: 95.8% (1222/1276)
# 處理表: 6278TW台表科
# 總進度: 95.8% (1223/1276)
# 處理表: 2887ETW
# 處理表: 1710TW東聯總進度: 95.9% (1224/1276)
#
# 總進度: 96.0% (1225/1276)
# 處理表: 5521TW工信
# 處理表: 1468TW昶和總進度: 96.1% (1226/1276)
#
# 總進度: 96.2% (1227/1276)處理表: 1256TW鮮活果汁-KY
#
# 總進度: 96.2% (1228/1276)
# 處理表: 3563TW牧德
# 處理表: 00951TW
# 總進度: 96.3% (1229/1276)
# 處理表: 00770TW
# 總進度: 96.4% (1230/1276)
# 處理表: 2887Z1TW
# 總進度: 96.5% (1231/1276)
# 總進度: 96.6% (1232/1276)
# 處理表: 5522TW遠雄
# 總進度: 96.6% (1233/1276)處理表: 00650LTW
#
# 總進度: 96.7% (1234/1276)
# 處理表: 2607TW榮運
# 處理表: 9907TW統一實總進度: 96.8% (1235/1276)
#
# 總進度: 96.9% (1236/1276)
# 總進度: 96.9% (1237/1276)
# 處理表: 2455TW全新
# 處理表: 8070TW長華*
# 總進度: 97.0% (1238/1276)
# 處理表: 2357TW華碩
# 總進度: 97.1% (1239/1276)
# 處理表: 6715TW嘉基
# 總進度: 97.2% (1240/1276)
# 總進度: 97.3% (1241/1276)
# 處理表: 2038TW海光
# 處理表: 6282TW康舒
# 總進度: 97.3% (1242/1276)處理表: 1711TW永光
#
# 總進度: 97.4% (1243/1276)
# 總進度: 97.5% (1244/1276)
# 處理表: 1470TW大統新創
# 處理表: 4576TW大銀微系統
# 總進度: 97.6% (1245/1276)
# 處理表: 8046TW南電
# 總進度: 97.6% (1246/1276)處理表: 1301TW台塑
#
# 處理表: 6719TW力智總進度: 97.7% (1247/1276)
#
# 總進度: 97.8% (1248/1276)
# 處理表: 00952TW
# 處理表: 3046TW建碁總進度: 97.9% (1249/1276)
#
# 處理表: 00771TW
# 總進度: 98.0% (1250/1276)
# 總進度: 98.0% (1251/1276)
# 處理表: 5525TW順天
# 處理表: 00651RTW
# 總進度: 98.1% (1252/1276)
# 總進度: 98.2% (1253/1276)處理表: 2609TW陽明
#
# 處理表: 9910TW豐泰總進度: 98.3% (1254/1276)
#
# 處理表: 2457TW飛宏
# 總進度: 98.4% (1255/1276)
# 總進度: 98.4% (1256/1276)處理表: 2359TW所羅門
#
# 總進度: 98.5% (1257/1276)
# 處理表: 2049TW上銀
# 總進度: 98.6% (1258/1276)
# 總進度: 98.7% (1259/1276)
# 處理表: 1712TW興農
# 處理表: 5531TW鄉林
# 總進度: 98.7% (1260/1276)處理表: 1471TW首利
#
# 總進度: 98.8% (1261/1276)
# 處理表: 4581TW光隆精密-KY
# 總進度: 98.9% (1262/1276)處理表: 8072TW陞泰
#
# 處理表: 1303TW南亞總進度: 99.0% (1263/1276)
#
# 處理表: 3576TW聯合再生
# 總進度: 99.1% (1264/1276)
# 總進度: 99.1% (1265/1276)
# 處理表: 00960TW
# 總進度: 99.2% (1266/1276)
# 處理表: 3047TW訊舟
# 總進度: 99.3% (1267/1276)處理表: 00775BTW
#
# 處理表: 2888TW新光金
# 總進度: 99.4% (1268/1276)
# 總進度: 99.5% (1269/1276)
# 總進度: 99.5% (1270/1276)
# 總進度: 99.6% (1271/1276)
# 總進度: 99.7% (1272/1276)
# 總進度: 99.8% (1273/1276)
# 總進度: 99.8% (1274/1276)
# 總進度: 99.9% (1275/1276)
# 總進度: 100.0% (1276/1276)
#
# 處理完成! 共補充 73426 筆數據
# 處理時間: 297.86 秒

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\a\documents\論文\b\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\a\documents\論文\b\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
